# %%
from input import *
code = get_code_from_file(sample_program)
chunks = [line.strip() for line in code.split("\n") if line.strip()]
for i,chunk in enumerate(chunks):
    print(f'{i} : {chunk}')
    print('-'*75)
#Creation of embeddings of file
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('nomic-ai/nomic-embed-text-v1.5', trust_remote_code=True)
embedding = model.encode(chunks)
print("Number of chunks: ", len(chunks))
print("Shape of embedding: ",embedding.shape)
#Creation of FAISS index
import faiss
import numpy as np
dimension = embedding.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(embedding).astype('float32'))
print("Number of vectors in the index: ", index.ntotal)
##converting user query to embedding and searching in the index
query = "What is the purpose of this code?"
query_embedding = model.encode([query])
k = 5  # Number of nearest neighbors to retrieve
D, I = index.search(np.array(query_embedding).astype('float32'),k)
print("Distances: ", D)
print("Indices: ", I)
for i in I[0]:
    print("Chunk: ", chunks[i])
    print('-'*75)
#printing the result
results = [chunks[i] for i in I[0]]
print("Results: ", results)
# Out:
# 0 : #lab program 5
# #lab program 5
# ---------------------------------------------------------------------------
# 1 : from collections import Counter
# from collections import Counter
# ---------------------------------------------------------------------------
# 2 : import pprint,operator
# import pprint,operator
# ---------------------------------------------------------------------------
# 3 : with open('sample.txt') as f: #1st way
# with open('sample.txt') as f: #1st way
# ---------------------------------------------------------------------------
# 4 : words = f.read().lower().split()
# words = f.read().lower().split()
# ---------------------------------------------------------------------------
# 5 : d = Counter(words)
# d = Counter(words)
# ---------------------------------------------------------------------------
# 6 : freq = d.most_common(10)
# freq = d.most_common(10)
# ---------------------------------------------------------------------------
# 7 : print("frequency of each word is: ")
# print("frequency of each word is: ")
# ---------------------------------------------------------------------------
# 8 : pprint.pprint(dict(d))
# pprint.pprint(dict(d))
# ---------------------------------------------------------------------------
# 9 : pprint.pprint(freq)
# pprint.pprint(freq)
# ---------------------------------------------------------------------------
# 10 : print("Second part after this")
# print("Second part after this")
# ---------------------------------------------------------------------------
# 11 : with open('sample.txt') as f: #2nd way
# with open('sample.txt') as f: #2nd way
# ---------------------------------------------------------------------------
# 12 : words = f.read().lower().split()
# words = f.read().lower().split()
# ---------------------------------------------------------------------------
# 13 : d= {}
# d= {}
# ---------------------------------------------------------------------------
# 14 : for i in words:
# for i in words:
# ---------------------------------------------------------------------------
# 15 : if i not in d:
# if i not in d:
# ---------------------------------------------------------------------------
# 16 : d[i] = 1
# d[i] = 1
# ---------------------------------------------------------------------------
# 17 : else:
# else:
# ---------------------------------------------------------------------------
# 18 : d[i] +=1
# d[i] +=1
# ---------------------------------------------------------------------------
# 19 : sorted_d = sorted(d.items(),key = operator.itemgetter(1),reverse = True)
# sorted_d = sorted(d.items(),key = operator.itemgetter(1),reverse = True)
# ---------------------------------------------------------------------------
# 20 : pprint.pprint(sorted_d)
# pprint.pprint(sorted_d)
# ---------------------------------------------------------------------------
# 21 : for i in sorted_d[:10]:
# for i in sorted_d[:10]:
# ---------------------------------------------------------------------------
# 22 : print(i)
# print(i)
# ---------------------------------------------------------------------------
# <All keys matched successfully>
# Number of chunks:  23
# Shape of embedding:  (23, 768)
# Number of vectors in the index:  23
# Distances:  [[452.70728 490.9502  490.9502  493.66876 511.75836]]
# Indices:  [[19  4 12 11  3]]
# Chunk:  sorted_d = sorted(d.items(),key = operator.itemgetter(1),reverse = True)
# ---------------------------------------------------------------------------
# Chunk:  words = f.read().lower().split()
# ---------------------------------------------------------------------------
# Chunk:  words = f.read().lower().split()
# ---------------------------------------------------------------------------
# Chunk:  with open('sample.txt') as f: #2nd way
# ---------------------------------------------------------------------------
# Chunk:  with open('sample.txt') as f: #1st way
# ---------------------------------------------------------------------------
# Results:  ['sorted_d = sorted(d.items(),key = operator.itemgetter(1),reverse = True)', 'words = f.read().lower().split()', 'words = f.read().lower().split()', "with open('sample.txt') as f: #2nd way", "with open('sample.txt') as f: #1st way"]
